# %% [markdown]
# <a href="https://colab.research.google.com/github/jkiawu7/colab-git-V2-Jkiawu7/blob/main/GitHub_Colab_Assign_2_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version # this code ensure that the GitHub has been installed in the Google Colab.
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "Jkiawu7"
# !git config --global user.email "jameskiawu7@gmail.com"
# !git config --global init.defaultBranch main

# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=Jkiawu7
# user.email=jameskiawu7@gmail.com
# init.defaultbranch=main

# %%
# !pwd # to verify current path for GitHub
# Out:
# /content

# %%
from getpass import getpass # to savely parse the token without exposing it.
token = getpass('Enter your GitHub token:')
# Out:
# Enter your GitHub token:··········

# %%
# !git clone https://Jkiawu7:{token}@github.com/Jkiawu7/colab-git-V1-Jkiawu7.git
# Out:
# Cloning into 'colab-git-V1-Jkiawu7'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd colab-git-V1-Jkiawu7
# Out:
# /content/colab-git-V1-Jkiawu7

# %%
# !git status # to check the git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# # Git and GitHub Assignment 2
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(2, 3))
# Out:
# 6

# %%
# !ls
# Out:
# assignment2.ipynb	   git_github_exercise.ipynb.  README.md
# git_github_exercise.ipynb  GitHub_Lab_2.ipynb

# %%
# Commit and Push the New Notebook Into GitHub
# !git add assignment2.ipynb
# !git commit -m "Added assignment2 notebook"
# !git push origin main
# Out:
# [main e950c24] Added assignment2 notebook
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 assignment2.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 288 bytes | 288.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/jkiawu7/colab-git-V1-Jkiawu7.git
# To https://github.com/Jkiawu7/colab-git-V1-Jkiawu7.git
#    60173c1..e950c24  main -> main

# %%
# !git checkout -b feature-branch
# Out:
# Switched to a new branch 'feature-branch'

# %%
def divide_numbers(a, b):
    if b != 0:
        return a / b
    else:
        return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
# !ls
# Out:
# assignment2.ipynb	   git_github_exercise.ipynb.  README.md
# git_github_exercise.ipynb  GitHub_Lab_2.ipynb

# %%
# !git add assignment2.ipynb
# !git commit -m "Added divide_numbers function to assignment2 notebook"
# Out:
# On branch feature-branch
# nothing to commit, working tree clean

# %%
# !git push origin feature-branch
# Out:
# Everything up-to-date
